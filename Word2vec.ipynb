# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahdi-Miri/Word2Vec/blob/main/Word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Word To Vector

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import gensim.downloader as api
from gensim.models import KeyedVectors
# %matplotlib inline

# %%
#model = api.load("glove-wiki-gigaword-100")
model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
print(type(model))
# Out:
# <class 'gensim.models.keyedvectors.KeyedVectors'>

# %%
model["bread"]
# Out:
# array([ 0.11181641,  0.02355957, -0.15039062,  0.24316406,  0.10302734,
#         0.16503906,  0.38476562, -0.32421875, -0.16308594, -0.02380371,
#        -0.13574219,  0.06225586, -0.15332031,  0.30273438, -0.20996094,
#         0.19335938, -0.04663086, -0.25585938, -0.09570312, -0.16210938,
#         0.06494141,  0.02880859,  0.09228516, -0.06298828,  0.15527344,
#         0.02587891, -0.07568359,  0.08105469, -0.08740234, -0.00817871,
#         0.01165771, -0.06982422,  0.15625   , -0.11376953, -0.03344727,
#         0.05737305, -0.11328125,  0.03540039, -0.00994873,  0.20703125,
#         0.07861328, -0.07617188,  0.15332031, -0.09912109,  0.06982422,
#         0.00744629,  0.0189209 ,  0.25585938, -0.07421875,  0.01586914,
#        -0.01660156,  0.05639648, -0.10742188, -0.06225586, -0.12597656,
#        -0.18359375, -0.06982422,  0.10693359, -0.1328125 , -0.15429688,
#         0.02526855,  0.2734375 , -0.00549316,  0.16992188,  0.12695312,
# ...

# %%
model["croissant"]
# Out:
# array([-0.03015137, -0.26953125,  0.06298828,  0.57421875,  0.19140625,
#         0.10742188,  0.43554688, -0.1171875 , -0.14160156,  0.2578125 ,
#        -0.4609375 ,  0.02258301,  0.18945312, -0.18945312, -0.15429688,
#         0.328125  , -0.16796875, -0.21484375,  0.25195312, -0.06030273,
#        -0.22460938,  0.1171875 ,  0.11035156, -0.12988281,  0.0267334 ,
#        -0.00567627, -0.140625  ,  0.06982422,  0.13378906,  0.13378906,
#         0.08300781, -0.28125   , -0.12988281, -0.00787354, -0.22851562,
#         0.03466797,  0.13085938,  0.08349609, -0.00692749,  0.33398438,
#        -0.28710938, -0.33203125,  0.14550781,  0.09570312,  0.34570312,
#        -0.19433594, -0.16796875,  0.23730469, -0.03662109,  0.09472656,
#        -0.18066406,  0.13476562, -0.01257324, -0.06298828, -0.21679688,
#         0.00958252,  0.26757812, -0.12304688, -0.18359375, -0.15527344,
#        -0.234375  ,  0.22167969,  0.08496094, -0.08056641, -0.00775146,
# ...

# %%
model.most_similar("man")
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
model.most_similar("car")
# Out:
# [('vehicle', 0.7821096181869507),
#  ('cars', 0.7423831224441528),
#  ('SUV', 0.7160962224006653),
#  ('minivan', 0.6907036900520325),
#  ('truck', 0.6735789775848389),
#  ('Car', 0.6677608489990234),
#  ('Ford_Focus', 0.667320191860199),
#  ('Honda_Civic', 0.6626849174499512),
#  ('Jeep', 0.651133120059967),
#  ('pickup_truck', 0.6441438794136047)]

# %%
model.most_similar("water")
# Out:
# [('potable_water', 0.6799106001853943),
#  ('Water', 0.6706871390342712),
#  ('sewage', 0.6619377732276917),
#  ('groundwater', 0.6588346362113953),
#  ('Floridan_aquifer', 0.6422534584999084),
#  ('surficial_aquifer', 0.64188551902771),
#  ('freshwater', 0.6307883262634277),
#  ('potable', 0.6251927614212036),
#  ('wastewater', 0.6212229132652283),
#  ('brackish_groundwater', 0.6206730604171753)]

# %%
model.most_similar(negative= "apple")
# Out:
# [('MotoTron_electronic_controls', 0.2328740507364273),
#  ('E.Sadler_###-###', 0.2295827865600586),
#  ('J.McMurray_###-###', 0.2271682173013687),
#  ('K.Kahne_###-###', 0.22496718168258667),
#  ('M.Kenseth_###-###', 0.21127989888191223),
#  ('Geeth_Narayanan', 0.20616959035396576),
#  ('Helix_ESG', 0.20473116636276245),
#  ('Sangh_Samachar', 0.2039283961057663),
#  ('topical_cationic_peptide', 0.203555166721344),
#  ('BIGFORK_Mont', 0.2033921480178833)]

# %%
result = model.most_similar(positive = ["woman","king"],negative = ["man"])
print("{}:{:.4f}".format(*result[0]))
# Out:
# queen:0.7118

# %%
def analogy(x1,x2,y1):
  result = model.most_similar(positive= [y1,x2], negative= [x1])
  return result[0][0]

# %%
analogy("man","king","woman")
# Out:
# 'queen'

# %%
analogy("dogs","animal","bug")
# Out:
# 'insect'

# %%
analogy("benz","vehicle","plane")
# Out:
# 'airplane'
